# %% [markdown]
# ## EShw03
# 1. 运行一个索引别名的例子， 截图
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. 运行一个滚动索引的例子， 截图
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. 实现冷热数据存储或者时序数据管理的案例， 二选一， 截图
# ![image.png](attachment:image.png)
