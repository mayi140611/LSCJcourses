# %% [markdown]
# ## EShw01

# %% [markdown]
# ### 1. 安装Elasticsearch、cerebro和kibana， 并截图

# %% [markdown]
# ES截图 浏览器输入：http://h1:9200/_cluster/health?pretty
# ![image.png](attachment:image.png)

# %% [markdown]
# cerebro截图  bin/cerebro -Dhttp.port=9001
#
# ![image.png](attachment:image.png)

# %% [markdown]
# kibana截图   http://h1:5601
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. 运行一个聚合的例子， 截图

# %% [markdown]
# ![image.png](attachment:image.png)
