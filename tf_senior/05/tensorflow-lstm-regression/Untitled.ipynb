# %%
from data_processing import *

# %%
import pandas as pd

# %%
rnn_data(pd.DataFrame({'a':[1, 2, 3, 4, 5]}),2,False)
# Out:
# array([[[1.],
#         [2.]],
#
#        [[2.],
#         [3.]],
#
#        [[3.],
#         [4.]]], dtype=float32)

# %%
rnn_data(pd.DataFrame({'a':[1, 2, 3, 4, 5]}),2,True)
# Out:
# array([[3.],
#        [4.],
#        [5.]], dtype=float32)
