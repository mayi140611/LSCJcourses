# %% [markdown]
# ## zfmlhw02

# %% [markdown]
# ### 1. 编程题
#
# 根据课程中给出的1958-1969年间的数据，分别构建一元线性回归模型和倒数模型表示的菲利普斯曲线。

# %%
import pandas as pd
from sklearn import linear_model
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('02/hw02data.csv',encoding='gbk')
df.head()
# Out:
#      年份  收入指数  失业率
# 0  1958   4.2  6.8
# 1  1959   3.5  5.5
# 2  1960   3.4  5.5
# 3  1961   3.0  6.7
# 4  1962   3.4  5.5

# %%
s = df['收入指数']

# %%
s.values
# Out:
# array([4.2, 3.5, 3.4, 3. , 3.4, 2.8, 2.8, 3.6, 4.3, 5. , 6.1, 6.7])

# %%
lm = linear_model.LinearRegression()

# %%
lm.fit(df['收入指数'].values[:,np.newaxis],df['失业率'].values)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.coef_, lm.intercept_
# Out:
# (array([-0.65367316]), 7.666604197901049)

# %% [markdown]
# 所以，一元线性模型：y = 7.666604197901049 -0.65367316X

# %%
lm1 = linear_model.LinearRegression()

# %%
lm1.fit(1 / df['收入指数'].values[:,np.newaxis],df['失业率'].values)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm1.coef_, lm1.intercept_
# Out:
# (array([11.49891929]), 1.9580649002612747)

# %%
plt.scatter(df['收入指数'].values[:,np.newaxis],df['失业率'].values)
plt.plot(df['收入指数'].values[:,np.newaxis], lm.predict(df['收入指数'].values[:,np.newaxis]))
plt.plot(df['收入指数'].values[:,np.newaxis], lm1.predict(1/df['收入指数'].values[:,np.newaxis]),color='red')
plt.show()

# %% [markdown]
# ### 2. 数学推导题
#
# 请你根据线性回归的通解，推导证明 上述关于一元线性回归最小二乘解 的结论。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. 实践题
#
# 由于接下来的课程中，会介绍开源深度学习框架 TensorFlow的使用，你需要在自己的电脑上搭建相应的环境。

# %% [markdown]
# tensorflow环境很早之前就已经安装好
#
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
# Out:
# /home/ian/installed/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
a = tf.constant(10)
b = tf.constant(32)
sess = tf.Session()
print(sess.run(a + b))
# Out:
# 42

# %%
sess.close()

# %% [markdown]
# ## end

# %% [markdown]
# ## end

# %% [markdown]
# ## end

# %% [markdown]
# ## end

# %% [markdown]
# ## end

# %% [markdown]
# ## end

# %% [markdown]
# ## end

# %% [markdown]
# ## end

# %% [markdown]
# ## end

# %% [markdown]
# ## end

# %% [markdown]
# ## end

# %% [markdown]
# ## end
