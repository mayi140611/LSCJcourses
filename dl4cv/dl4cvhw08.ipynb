# %% [markdown]
# ## dl4cvhw08
#
# ### keras+mnist,跑出tensorboard的运行结果

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
