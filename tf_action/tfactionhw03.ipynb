# %% [markdown]
# ## tfactionhw03
# 目前聊天机器人有很多开源的程序，尝试寻找一个合适的框架，训练一个聊天机器人
# 过程与结果截图上传

# %% [markdown]
# ### 下载数据

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### train

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### test

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
